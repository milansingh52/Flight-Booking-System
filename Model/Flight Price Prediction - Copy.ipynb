# %%
import pandas as pd

# %%
df = pd.read_csv('Clean_Dataset1.csv')

# %%
df
# Out:
#         Unnamed: 0        airline   flight source_city departure_time stops  \
# 0                0     Buddha_Air  SG-8709   Kathmandu        Evening  zero
# 1                1     Buddha_Air  SG-8157   Kathmandu  Early_Morning  zero
# 2                2     Summit_Air   I5-764   Kathmandu  Early_Morning  zero
# 3                3  Yeti_Airlines   UK-995   Kathmandu        Morning  zero
# 4                4  Yeti_Airlines   UK-963   Kathmandu        Morning  zero
# ...            ...            ...      ...         ...            ...   ...
# 300148      300148  Yeti_Airlines   UK-822    Janakpur        Morning   one
# 300149      300149  Yeti_Airlines   UK-826    Janakpur      Afternoon   one
# 300150      300150  Yeti_Airlines   UK-832    Janakpur  Early_Morning   one
# 300151      300151  Yeti_Airlines   UK-828    Janakpur  Early_Morning   one
# 300152      300152  Yeti_Airlines   UK-822    Janakpur        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# 0               Night       Bhairahawa   Economy      2.17          1   5953
# 1             Morning       Bhairahawa   Economy      2.33          1   5953
# 2       Early_Morning       Bhairahawa   Economy      2.17          1   5956
# 3           Afternoon       Bhairahawa   Economy      2.25          1   5955
# 4             Morning       Bhairahawa   Economy      2.33          1   5955
# ...               ...              ...       ...       ...        ...    ...
# 300148        Evening        Nepalgunj  Business     10.08         49  69265
# 300149          Night        Nepalgunj  Business     10.42         49  77105
# 300150          Night        Nepalgunj  Business     13.83         49  79099
# 300151        Evening        Nepalgunj  Business     10.00         49  81585
# 300152        Evening        Nepalgunj  Business     10.08         49  81585
#
# [300153 rows x 12 columns]

# %%
df.rename(columns={'class': 'air_class',}, inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0        airline   flight source_city departure_time stops  \
# 0           0     Buddha_Air  SG-8709   Kathmandu        Evening  zero
# 1           1     Buddha_Air  SG-8157   Kathmandu  Early_Morning  zero
# 2           2     Summit_Air   I5-764   Kathmandu  Early_Morning  zero
# 3           3  Yeti_Airlines   UK-995   Kathmandu        Morning  zero
# 4           4  Yeti_Airlines   UK-963   Kathmandu        Morning  zero
#
#     arrival_time destination_city air_class  duration  days_left  price
# 0          Night       Bhairahawa   Economy      2.17          1   5953
# 1        Morning       Bhairahawa   Economy      2.33          1   5953
# 2  Early_Morning       Bhairahawa   Economy      2.17          1   5956
# 3      Afternoon       Bhairahawa   Economy      2.25          1   5955
# 4        Morning       Bhairahawa   Economy      2.33          1   5955

# %%
df['airline'].value_counts()
# Out:
# airline
# Yeti_Airlines      127859
# Tara_Air            80892
# Saurya_Airlines     43120
# Shree_Airlines      23173
# Summit_Air          16098
# Buddha_Air           9011
# Name: count, dtype: int64

# %%
df['source_city'].value_counts()
# Out:
# source_city
# Kathmandu     61343
# Bhairahawa    60896
# Pokhara       52061
# Biratnagar    46347
# Nepalgunj     40806
# Janakpur      38700
# Name: count, dtype: int64

# %%
df['destination_city'].value_counts()
# Out:
# destination_city
# Bhairahawa    59097
# Kathmandu     57360
# Makanpur      40368
# Jumla         36623
# Lumbini       34564
# Tulsipur      26897
# Pokhara       24171
# Biratnagar    14970
# Nepalgunj      6103
# Name: count, dtype: int64

# %%
df['departure_time'].value_counts()
# Out:
# departure_time
# Morning          71146
# Early_Morning    66790
# Evening          65102
# Night            48015
# Afternoon        47794
# Late_Night        1306
# Name: count, dtype: int64

# %%
df['arrival_time'].value_counts()
# Out:
# arrival_time
# Night            91538
# Evening          78323
# Morning          62735
# Afternoon        38139
# Early_Morning    15417
# Late_Night       14001
# Name: count, dtype: int64

# %%
df['stops'].value_counts()
# Out:
# stops
# one            250863
# zero            36004
# two_or_more     13286
# Name: count, dtype: int64

# %%
df['air_class'].value_counts()
# Out:
# air_class
# Economy     206666
# Business     93487
# Name: count, dtype: int64

# %%
df['duration'].min()
# Out:
# np.float64(0.83)

# %%
df['duration'].max()
# Out:
# np.float64(49.83)

# %%
df['duration'].median()
# Out:
# np.float64(11.25)

# %% [markdown]
# # Preprocessing

# %%
df = df.drop('Unnamed: 0', axis=1)
df = df.drop('flight', axis=1)

# %%
df['air_class'] = df['air_class'].apply(lambda x: 1 if x == 'Business' else 0)

# %%
df.sample(5)
# Out:
#                 airline source_city departure_time stops arrival_time  \
# 147056  Saurya_Airlines  Biratnagar        Evening   one        Night
# 171103  Saurya_Airlines   Nepalgunj        Morning   one        Night
# 21636    Shree_Airlines   Kathmandu        Evening   one        Night
# 76173        Summit_Air  Bhairahawa      Afternoon   one      Evening
# 86863     Yeti_Airlines     Pokhara          Night   one      Morning
#
#        destination_city  air_class  duration  days_left  price
# 147056            Jumla          0      5.33         41   4367
# 171103       Biratnagar          0      8.67          6   5293
# 21636           Lumbini          0      6.58         11   5954
# 76173             Jumla          0      4.67         42   2105
# 86863         Kathmandu          0     12.00         16   4796

# %%
df['stops'] = pd.factorize(df['stops'])[0]

# %%
df.sample(5)
# Out:
#                 airline source_city departure_time  stops arrival_time  \
# 84759     Yeti_Airlines     Pokhara        Morning      1      Evening
# 271479         Tara_Air  Biratnagar        Morning      1      Morning
# 6911      Yeti_Airlines   Kathmandu      Afternoon      1      Morning
# 103763       Buddha_Air     Pokhara      Afternoon      1        Night
# 58284   Saurya_Airlines  Bhairahawa        Morning      1    Afternoon
#
#        destination_city  air_class  duration  days_left  price
# 84759         Kathmandu          0     32.00          5  12286
# 271479            Jumla          1     24.08         27  52063
# 6911         Bhairahawa          0     21.83         35   4381
# 103763          Lumbini          0      5.75         10   5177
# 58284          Tulsipur          0      5.17         32   2124

# %%
df = df.join(pd.get_dummies(df['airline'], prefix='airline')).drop(['airline'], axis=1)
df = df.join(pd.get_dummies(df['source_city'], prefix='source')).drop(['source_city'], axis=1)
df = df.join(pd.get_dummies(df['destination_city'], prefix='dest')).drop(['destination_city'], axis=1)
df = df.join(pd.get_dummies(df['arrival_time'], prefix='arrival')).drop(['arrival_time'], axis=1)
df = df.join(pd.get_dummies(df['departure_time'], prefix='departure')).drop(['departure_time'], axis=1)

# %%
df.sample(5)
# Out:
#         stops  air_class  duration  days_left  price  airline_Buddha_Air  \
# 269246      1          1      9.83         33  60978               False
# 184534      1          0     33.83         30   7476               False
# 8615        1          0     20.83         43   3291               False
# 125830      1          0      6.42         40   2994               False
# 152607      1          0     13.42          2  12276               False
#
#         airline_Saurya_Airlines  airline_Shree_Airlines  airline_Summit_Air  \
# 269246                    False                   False               False
# 184534                    False                   False               False
# 8615                      False                   False               False
# 125830                     True                   False               False
# 152607                    False                   False               False
#
#         airline_Tara_Air  ...  arrival_Evening  arrival_Late_Night  \
# 269246             False  ...             True               False
# 184534             False  ...             True               False
# 8615                True  ...            False               False
# 125830             False  ...            False               False
# 152607             False  ...            False               False
#
#         arrival_Morning  arrival_Night  departure_Afternoon  \
# 269246            False          False                False
# 184534            False          False                False
# 8615              False          False                False
# 125830            False           True                False
# 152607             True          False                False
#
#         departure_Early_Morning  departure_Evening  departure_Late_Night  \
# 269246                     True              False                 False
# 184534                     True              False                 False
# 8615                      False               True                 False
# 125830                    False               True                 False
# 152607                    False              False                 False
#
#         departure_Morning  departure_Night
# 269246              False            False
# 184534              False            False
# 8615                False            False
# 125830              False            False
# 152607              False             True
#
# [5 rows x 38 columns]

# %%
df.columns
# Out:
# Index(['stops', 'air_class', 'duration', 'days_left', 'price',
#        'airline_Buddha_Air', 'airline_Saurya_Airlines',
#        'airline_Shree_Airlines', 'airline_Summit_Air', 'airline_Tara_Air',
#        'airline_Yeti_Airlines', 'source_Bhairahawa', 'source_Biratnagar',
#        'source_Janakpur', 'source_Kathmandu', 'source_Nepalgunj',
#        'source_Pokhara', 'dest_Bhairahawa', 'dest_Biratnagar', 'dest_Jumla',
#        'dest_Kathmandu', 'dest_Lumbini', 'dest_Makanpur', 'dest_Nepalgunj',
#        'dest_Pokhara', 'dest_Tulsipur', 'arrival_Afternoon',
#        'arrival_Early_Morning', 'arrival_Evening', 'arrival_Late_Night',
#        'arrival_Morning', 'arrival_Night', 'departure_Afternoon',
#        'departure_Early_Morning', 'departure_Evening', 'departure_Late_Night',
#        'departure_Morning', 'departure_Night'],
#       dtype='object')

# %%
df['air_class'].unique()
# Out:
# array([0, 1])

# %%
df = df.drop('duration', axis=1)

# %% [markdown]
# # Training Regression Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor

# %%
X, y = df.drop('price', axis=1), df['price']

# %%
X
# Out:
#         stops  air_class  days_left  airline_Buddha_Air  \
# 0           0          0          1                True
# 1           0          0          1                True
# 2           0          0          1               False
# 3           0          0          1               False
# 4           0          0          1               False
# ...       ...        ...        ...                 ...
# 300148      1          1         49               False
# 300149      1          1         49               False
# 300150      1          1         49               False
# 300151      1          1         49               False
# 300152      1          1         49               False
#
#         airline_Saurya_Airlines  airline_Shree_Airlines  airline_Summit_Air  \
# 0                         False                   False               False
# 1                         False                   False               False
# 2                         False                   False                True
# 3                         False                   False               False
# 4                         False                   False               False
# ...                         ...                     ...                 ...
# 300148                    False                   False               False
# 300149                    False                   False               False
# 300150                    False                   False               False
# 300151                    False                   False               False
# 300152                    False                   False               False
#
#         airline_Tara_Air  airline_Yeti_Airlines  source_Bhairahawa  ...  \
# 0                  False                  False              False  ...
# 1                  False                  False              False  ...
# 2                  False                  False              False  ...
# 3                  False                   True              False  ...
# 4                  False                   True              False  ...
# ...                  ...                    ...                ...  ...
# 300148             False                   True              False  ...
# 300149             False                   True              False  ...
# 300150             False                   True              False  ...
# 300151             False                   True              False  ...
# 300152             False                   True              False  ...
#
#         arrival_Evening  arrival_Late_Night  arrival_Morning  arrival_Night  \
# 0                 False               False            False           True
# 1                 False               False             True          False
# 2                 False               False            False          False
# 3                 False               False            False          False
# 4                 False               False             True          False
# ...                 ...                 ...              ...            ...
# 300148             True               False            False          False
# 300149            False               False            False           True
# 300150            False               False            False           True
# 300151             True               False            False          False
# 300152             True               False            False          False
#
#         departure_Afternoon  departure_Early_Morning  departure_Evening  \
# 0                     False                    False               True
# 1                     False                     True              False
# 2                     False                     True              False
# 3                     False                    False              False
# 4                     False                    False              False
# ...                     ...                      ...                ...
# 300148                False                    False              False
# 300149                 True                    False              False
# 300150                False                     True              False
# 300151                False                     True              False
# 300152                False                    False              False
#
#         departure_Late_Night  departure_Morning  departure_Night
# 0                      False              False            False
# 1                      False              False            False
# 2                      False              False            False
# 3                      False               True            False
# 4                      False               True            False
# ...                      ...                ...              ...
# 300148                 False               True            False
# 300149                 False              False            False
# 300150                 False              False            False
# 300151                 False              False            False
# 300152                 False               True            False
#
# [300153 rows x 36 columns]

# %%
X.columns
# Out:
# Index(['stops', 'air_class', 'days_left', 'airline_Buddha_Air',
#        'airline_Saurya_Airlines', 'airline_Shree_Airlines',
#        'airline_Summit_Air', 'airline_Tara_Air', 'airline_Yeti_Airlines',
#        'source_Bhairahawa', 'source_Biratnagar', 'source_Janakpur',
#        'source_Kathmandu', 'source_Nepalgunj', 'source_Pokhara',
#        'dest_Bhairahawa', 'dest_Biratnagar', 'dest_Jumla', 'dest_Kathmandu',
#        'dest_Lumbini', 'dest_Makanpur', 'dest_Nepalgunj', 'dest_Pokhara',
#        'dest_Tulsipur', 'arrival_Afternoon', 'arrival_Early_Morning',
#        'arrival_Evening', 'arrival_Late_Night', 'arrival_Morning',
#        'arrival_Night', 'departure_Afternoon', 'departure_Early_Morning',
#        'departure_Evening', 'departure_Late_Night', 'departure_Morning',
#        'departure_Night'],
#       dtype='object')

# %%
y
# Out:
# 0          5953
# 1          5953
# 2          5956
# 3          5955
# 4          5955
#           ...
# 300148    69265
# 300149    77105
# 300150    79099
# 300151    81585
# 300152    81585
# Name: price, Length: 300153, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#         stops  air_class  days_left  airline_Buddha_Air  \
# 229620      1          1         46               False
# 107719      1          0         36               False
# 178034      1          0         22               False
# 207009      0          1          5               False
# 216922      1          1         17               False
# ...       ...        ...        ...                 ...
# 293569      1          1          5               False
# 227540      1          1         26               False
# 128867      2          0         11               False
# 199814      0          0         22                True
# 121289      1          0         13               False
#
#         airline_Saurya_Airlines  airline_Shree_Airlines  airline_Summit_Air  \
# 229620                    False                   False               False
# 107719                    False                   False               False
# 178034                    False                   False               False
# 207009                    False                   False               False
# 216922                    False                   False               False
# ...                         ...                     ...                 ...
# 293569                    False                   False               False
# 227540                    False                   False               False
# 128867                    False                   False               False
# 199814                    False                   False               False
# 121289                    False                    True               False
#
#         airline_Tara_Air  airline_Yeti_Airlines  source_Bhairahawa  ...  \
# 229620              True                  False               True  ...
# 107719              True                  False              False  ...
# 178034             False                   True              False  ...
# 207009             False                   True              False  ...
# 216922             False                   True              False  ...
# ...                  ...                    ...                ...  ...
# 293569             False                   True              False  ...
# 227540              True                  False               True  ...
# 128867              True                  False              False  ...
# 199814             False                  False              False  ...
# 121289             False                  False              False  ...
#
#         arrival_Evening  arrival_Late_Night  arrival_Morning  arrival_Night  \
# 229620            False               False            False           True
# 107719            False               False            False           True
# 178034            False               False             True          False
# 207009            False               False             True          False
# 216922            False               False             True          False
# ...                 ...                 ...              ...            ...
# 293569            False               False             True          False
# 227540            False               False            False           True
# 128867            False               False             True          False
# 199814            False               False             True          False
# 121289            False               False             True          False
#
#         departure_Afternoon  departure_Early_Morning  departure_Evening  \
# 229620                False                    False              False
# 107719                 True                    False              False
# 178034                False                    False               True
# 207009                False                    False              False
# 216922                False                    False               True
# ...                     ...                      ...                ...
# 293569                False                    False              False
# 227540                False                     True              False
# 128867                False                    False              False
# 199814                False                     True              False
# 121289                False                    False              False
#
#         departure_Late_Night  departure_Morning  departure_Night
# 229620                 False               True            False
# 107719                 False              False            False
# 178034                 False              False            False
# 207009                 False               True            False
# 216922                 False              False            False
# ...                      ...                ...              ...
# 293569                 False              False             True
# 227540                 False              False            False
# 128867                 False              False             True
# 199814                 False              False            False
# 121289                 False              False             True
#
# [240122 rows x 36 columns]

# %%
y_train
# Out:
# 229620    39847
# 107719     6583
# 178034    10225
# 207009    36712
# 216922    73369
#           ...
# 293569    67697
# 227540    59021
# 128867    12054
# 199814     4620
# 121289     6995
# Name: price, Length: 240122, dtype: int64

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
gr = GradientBoostingRegressor()
gr.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
rf = RandomForestRegressor(n_jobs=-1)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

gr = GradientBoostingRegressor()
gr.fit(X_train, y_train)

rf = RandomForestRegressor(n_jobs=-1)
rf.fit(X_train, y_train)

y_pred1 = lr.predict(X_test)
y_pred2 = gr.predict(X_test)
y_pred3 = rf.predict(X_test)

df1 = pd.DataFrame({'Actual': y_test, 'Lr': y_pred1, 'gr':y_pred2, 'rf':y_pred3})
df1
# Out:
#         Actual         Lr            gr            rf
# 267957   60978  54386.125  54733.565702  60978.000000
# 107519    3943   7467.250   5495.860118   3943.000000
# 150646    6125   8731.875   5505.042860   6285.010000
# 55046     5102   3390.625   5166.648116   5148.440000
# 159417   11319  11140.125  12552.801006  13631.990697
# ...        ...        ...           ...           ...
# 33463    17437   1930.500   4829.129082   5324.996024
# 194273   12318  12047.375  12086.050100  12857.766694
# 36564    11940   9274.875  10691.719875  11878.456667
# 128282   13695  16808.625  13935.165958  12242.971952
# 166066    4454  -2222.500   5526.428704   4454.000000
#
# [60031 rows x 4 columns]

# %%
rf.score(X_test, y_test)
# Out:
# 0.9623100771716364

# %%
import math
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y_pred = rf.predict(X_test)

print('R2:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
print('MSE:', mean_squared_error(y_test, y_pred))
print('RMSE', math.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2: 0.9623100771716364
# MAE: 2166.1659158355283
# MSE: 19456891.12171219
# RMSE 4410.996613205703

# %%
df['price'].describe()
# Out:
# count    300153.000000
# mean      20889.660523
# std       22697.767366
# min        1105.000000
# 25%        4783.000000
# 50%        7425.000000
# 75%       42521.000000
# max      123071.000000
# Name: price, dtype: float64

# %% [markdown]
# # Random Forest Implementation

# %%
import numpy as np
import random

# Define a class for the Decision Tree
class DecisionTreeRegressor:
    def __init__(self, max_depth=None, min_samples_split=2):
        self.max_depth = max_depth
        self.min_samples_split = min_samples_split
        self.tree = None
    
    # Train the tree
    def fit(self, X, y):
        self.tree = self._grow_tree(X, y)

    def _grow_tree(self, X, y, depth=0):
        num_samples, num_features = X.shape
        if depth >= self.max_depth or num_samples < self.min_samples_split:
            return np.mean(y)
        
        # Find the best split
        best_feature, best_threshold = self._best_split(X, y)
        if best_feature is None:
            return np.mean(y)
        
        # Split the data
        left_idxs, right_idxs = self._split(X[:, best_feature], best_threshold)
        left_tree = self._grow_tree(X[left_idxs], y[left_idxs], depth + 1)
        right_tree = self._grow_tree(X[right_idxs], y[right_idxs], depth + 1)
        return {"feature": best_feature, "threshold": best_threshold, "left": left_tree, "right": right_tree}
    
    def _best_split(self, X, y):
        num_samples, num_features = X.shape
        if num_samples <= 1:
            return None, None
        
        # Calculate variance of the current node
        best_feature, best_threshold = None, None
        best_mse = float('inf')
        
        for feature in range(num_features):
            thresholds = np.unique(X[:, feature])
            for threshold in thresholds:
                left_idxs, right_idxs = self._split(X[:, feature], threshold)
                if len(left_idxs) == 0 or len(right_idxs) == 0:
                    continue
                
                mse = self._calculate_mse(y[left_idxs], y[right_idxs])
                if mse < best_mse:
                    best_mse = mse
                    best_feature, best_threshold = feature, threshold
                    
        return best_feature, best_threshold
    
    def _split(self, X_column, threshold):
        left_idxs = np.argwhere(X_column <= threshold).flatten()
        right_idxs = np.argwhere(X_column > threshold).flatten()
        return left_idxs, right_idxs
    
    def _calculate_mse(self, left_y, right_y):
        left_mse = np.var(left_y) * len(left_y)
        right_mse = np.var(right_y) * len(right_y)
        return (left_mse + right_mse) / (len(left_y) + len(right_y))
    
    # Prediction
    def predict(self, X):
        return np.array([self._predict_row(row, self.tree) for row in X])
    
    def _predict_row(self, row, tree):
        if not isinstance(tree, dict):
            return tree
        
        feature = tree['feature']
        threshold = tree['threshold']
        
        if row[feature] <= threshold:
            return self._predict_row(row, tree['left'])
        else:
            return self._predict_row(row, tree['right'])

# Step 3: Implement Random Forest
class RandomForestRegressorFromScratch:
    def __init__(self, n_estimators=10, max_depth=None, min_samples_split=2):
        self.n_estimators = n_estimators
        self.max_depth = max_depth
        self.min_samples_split = min_samples_split
        self.trees = []
    
    def fit(self, X, y):
        self.trees = []
        for _ in range(self.n_estimators):
            X_sample, y_sample = self._bootstrap_sample(X, y)
            tree = DecisionTreeRegressor(max_depth=self.max_depth, min_samples_split=self.min_samples_split)
            tree.fit(X_sample, y_sample)
            self.trees.append(tree)
    
    def _bootstrap_sample(self, X, y):
        n_samples = X.shape[0]
        idxs = np.random.choice(n_samples, n_samples, replace=True)
        return X[idxs], y[idxs]
    
    def predict(self, X):
        # Collect predictions from all trees
        tree_preds = np.array([tree.predict(X) for tree in self.trees])
        return np.mean(tree_preds, axis=0)

# Step 4: Training the Random Forest
rf_scratch = RandomForestRegressorFromScratch(n_estimators=10, max_depth=5)
rf_scratch.fit(X_train.values, y_train.values)

# Step 5: Predictions and Evaluation
y_pred_scratch = rf_scratch.predict(X_test.values)
print(y_pred_scratch)
# Out:
# [51925.34151658  5962.60572085  5962.60572085 ... 12116.49169276
#   9807.29951958  6012.31715021]

# %%
# Evaluating the results
print('R2:', r2_score(y_test, y_pred_scratch))
print('MAE:', mean_absolute_error(y_test, y_pred_scratch))
print('MSE:', mean_squared_error(y_test, y_pred_scratch))
print('RMSE:', math.sqrt(mean_squared_error(y_test, y_pred_scratch)))
# Out:
# R2: 0.9415285321040412
# MAE: 3229.2899059634033
# MSE: 30185070.682134762
# RMSE: 5494.094163930462

# %% [markdown]
# # Save the model

# %%
# import pickle
# # with open('flight_rf3.pkl', 'wb') as file:
#     # Dump the trained model into the file
#     pickle.dump(reg, file)

# %%
# model = open('flight_rf3.pkl','rb')
# forest = pickle.load(model)

# %%
# y_prediction = forest.predict(X_test)

# %%
#y_pred = reg.predict(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 y_pred = reg.predict(X_train)
#
# NameError: name 'reg' is not defined

# %%
# Create a DataFrame for comparison
comparison_df = pd.DataFrame({'Actual': y_train, 'Predicted': y_pred, 'Error': y_train - y_pred})

# Display the first few rows of the comparison table
print(comparison_df.head())
